# %% [markdown]
# # Phase V
# ## Joseph Princiotta & Justin Lusk
# #### CYBER 363 Fall 2022

# %% [markdown]
# ## Part A
# ### Problem Introduction & Statements
#
# The (Hypothetical) CIO of Billy's Accounting Inc. approached the cybersecurity data team to explore the use of a machine training algorithm to help filter malicious websites from the companies' network. In the past year Billy's Accounting Inc. network had seen a 40% increase in malicious domains accessed on the network; causing the firewall and network team to become overloaded. The network security team's initial approach to halting malicious websites was done manually, with teammembers having to update the firewall's access control lists each week with newly encountered malicious website data. This process was time consuming and is only reactive, the team could only block malicious websites after they had been discovered.
#
# The CIO tasked the cyber data team with exploring the automating of discovery and blocking of malicious website data on the companies' networks. If implemented properly this would save thousands of man hours and would provide a proactive solution. This would increase the security of the network and increase the speed of discovering malicious websites.
#
# The cyber data team was given a dataset of recent website data which included 37 categories of website data and an identifier if the website was malicious or not. This dataset was used to test and train a suitable ML algorithm to predict risky websites proactivly.

# %% [markdown]
# ### Summary of process
#
#
# The first model we decided to try was a Decision Random Forests. We decided to test a random forest model because the use the average of many decision trees to make its prediction, which means they usually perform better than a single decision tree. We tried different values by using cross validation to determine the best values for n_estimators and max_depth by using cross validation. Increasing the amount of estimators increased the accuarcy slightly but also increased the computation time. The vizualization proccess showed that as max_depth was increasing accuracy until it hit max_depth = 7 then accuracy started to decrease.
#
# We decided to use the Support Vector Classifier because it is a discriminativve classifier. Discriminitive classifiers are good at drawing a line between data clusters. Since we are trying to determine whether a email either is or is not a phishing email and having a relatively small amount of data makes it well suited for the prediction we are trying to make. To test the model we used K-Fold cross validation. We chose K-Fold because it tries multiple different training models and combines each round from the different models and the validation results to give us estimate of the models performance. It also helps us determine the best way to spilt our data. To do this we used a GridSearch beacuse it performs an exhaustive search and evaluates its performance. GridSearch gave us the best parameters to use with our model. We then used this data to build the final SVC model and test the metrics.

# %% [markdown]
# ### Phase 0 & 1 Data Preprocessing and Feature Selection

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Sat Dec 10 19:52:38 2022

@author: jprince
"""

### Phase 0/1 Code.
import scipy.cluster.hierarchy as sch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.neighbors import LocalOutlierFactor
from sklearn.preprocessing import StandardScaler

#dfTest = pd.read_csv(r"C:\Users\jlusk\OneDrive\Desktop\CYB-362-main (1)\CYB-362-main\Phishing_Legitimate_test_student.csv", na_values=['',' ','n/a'],encoding='utf8')
#dfTrain = pd.read_csv(r"C:\Users\jlusk\OneDrive\Desktop\CYB-362-main (1)\CYB-362-main\Phishing_Legitimate_train_missing_data.csv", na_values=['',' ','n/a'],encoding='utf8')

dfTest = pd.read_csv("Phishing_Legitimate_test_student.csv", na_values=['',' ','n/a'])
dfTrain = pd.read_csv("Phishing_Legitimate_train_missing_data.csv", na_values=['',' ','n/a'])
################################# Phase 0 and 1 ####################################################
trainRowsWithNa = dfTrain[ dfTrain.isnull().any(axis=1) ]
rowsToDrop = dfTrain[ dfTrain.isnull().sum(axis=1) > 1 ].index
dfTrain.drop(rowsToDrop, inplace=True)
imputer = KNNImputer(n_neighbors=10)
dfTrain2 = pd.DataFrame(imputer.fit_transform(dfTrain),columns = dfTrain.columns)
rows_to_drop=dfTrain2[dfTrain2['UrlLength']>500].index
dfTrain2.drop(rows_to_drop,inplace=True)
rows_to_drop=dfTrain2[dfTrain2['NumNumericChars']>100].index
dfTrain2.drop(rows_to_drop,inplace=True)
rows_to_drop=dfTrain2[dfTrain2['NumDash']>20].index
dfTrain2.drop(rows_to_drop,inplace=True)
dfTrain2Numerical = dfTrain2[['NumNumericChars','NumDots','SubdomainLevel','PathLevel','UrlLength','NumDash','NumDashInHostname',
          'NumUnderscore','NumPercent','NumQueryComponents','NumAmpersand','NumHash','HostnameLength','PathLength','QueryLength','NumSensitiveWords']]
clf= LocalOutlierFactor(n_neighbors=20)
X=dfTrain2Numerical.to_numpy()
outlier_label=clf.fit_predict(X)
rows_to_drop= dfTrain2.iloc[clf.negative_outlier_factor_ < -1.30].index
dfTrain2.drop(rows_to_drop,inplace=True)
dfTrain2Numerical = dfTrain2[['NumNumericChars','NumDots','SubdomainLevel','PathLevel','UrlLength','NumDash','NumDashInHostname','NumUnderscore','NumPercent','NumQueryComponents','NumAmpersand','NumHash','HostnameLength','PathLength','QueryLength','NumSensitiveWords']]
X = dfTrain2Numerical.to_numpy()
scaler = StandardScaler()
scaler.fit(X)
X = scaler.transform(X)
dfTrain2Numerical.is_copy = False
dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X

## Phase 3/4 Code.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Create dataframe of target 'CLASS_LABEL'
dfClass_labels = pd.DataFrame(dfTrain2['CLASS_LABEL'])

# Create dataframe of standardized numerical features
dfTrain2Numstd= dfTrain2Numerical[['UrlLength_Standardized','NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]

# Created dataframe of all binary data, now binary and standardized numerical features can be seperated IF NEEDED.
dfTrain2Bin= dfTrain2[['AtSymbol','TildeSymbol','NoHttps','RandomString','IpAddress','DomainInSubdomains','DomainInPaths','DoubleSlashInPath','EmbeddedBrandName','PctExtResourceUrls','ExtFavicon','InsecureForms','RelativeFormAction','ExtFormAction','RightClickDisabled','PopUpWindow','IframeOrFrame','MissingTitle','ImagesOnlyInForm']]
# dfTrain2Bin contains binary features and dfTrain2Numstd contains standardized numerical data. 

# Create main dataframe that contains standardized numerical data and binary data
dfTrain3=dfTrain2Bin.join(dfTrain2Numstd)
# Create list of all features
featurecols=dfTrain3.columns.to_list()

# Create seperate lists for numerical & binary features lists
NUMfeaturecols=dfTrain2Numstd.columns.to_list()
BINfeaturecols=dfTrain2Bin.columns.to_list()

####### Dataframe list: ######
# 'dfTrain3' = Main dataframe of training data, std numerical and binary data 
# 'featurecols' = list of all feature cols in 'dfTrain3'
# 'NUMfeaturecols' = list of all numerical features 
# 'BINfeaturecols' = list of all binary features
# 'dfTrain2Bin' = all binary features 
# 'dfTrain2Numstd' = all numerical features standardized

# Create dataframe of target 'CLASS_LABEL'
dfClass_labels = pd.DataFrame(dfTrain2['CLASS_LABEL'])
# Add 'dfClass_labels' to main dfTrain3 
dfTrain3 = dfTrain3.join(dfClass_labels)
# Out:
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X
# /var/folders/_4/hwjprh3j6wl6k6dfccg50w0c0000gn/T/ipykernel_6240/2026943093.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfTrain2Numerical[['NumNumericChars_Standardized','NumDots_Standardized','SubdomainLevel_Standardized','PathLevel_Standardized','UrlLength_Standardized','NumDash_Standardized','NumDashInHostname_Standardized','NumUnderscore_Standardized','NumPercent_Standardized','NumQueryComponents_Standardized','NumAmpersand_Standardized','NumHash_Standardized','HostnameLength_Standardized','PathLength_Standardized','QueryLength_Standardized','NumSensitiveWords_Standardized']]=X

# %% [markdown]
# #### Feature Selection based on previous phases.
#
# 1. 'NumDash_Standardized'
# 2. 'PathLength_Standardized'
# 3. 'UrlLength_Standardized'
# 4. 'PathLevel_Standardized'
# 5. 'DomainInPaths'
# 6. 'RandomString'
# 7. 'InsecureForms'

# %% [markdown]
# ## Phase V
# Three types of ML models were tested, Random Forest, decision tree classifier and SVM classification.
#
# ##### First steps are to build dataframe of final selected features and perform training/testing data split (50/50)

# %%
# make dataframe features only selected features
dfFeatures=dfTrain3[['NumDash_Standardized','PathLength_Standardized','UrlLength_Standardized','PathLevel_Standardized','DomainInPaths','RandomString','InsecureForms']]
Y=dfTrain3['CLASS_LABEL']
X=dfFeatures

# Split data into training/testing 50/50
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,test_size=0.50,shuffle=False,random_state=1)

# %% [markdown]
# ## Decison Tree & Random Forest algorithm
# A random forests is multiple different decision trees and the average of the predictions from those trees is used to make its prediction.

# %% [markdown]
# ### Random Forests HyperParameter selection
# n_esitmators is set to 1000. The higher the n_estimators value, the better the performance and the more stable the predictions. The default of 100 n_estimators gave us an accuracy score of 0.82. n_estimators was increased to 1000 to increase performance. I didnt choose a higher because of the long computation times.
#
# The first optimization for these algorithms is to find the best maxdepth of the trees
#
# ### Tree & Forest Optimization to find best max_depth
# Using a for loop to test a range of maxdepth from 1-10 and plotting the Prection, Recall & F1 scores for each depth of the tree

# %%
## Optimizing the decison tree, finding the best maxdepth
#initilize arrays to hold precision, recall, f1 scores 
from sklearn import tree
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
pre=[]
recall=[]
f1=[]
#these are the maximum depth values to experiment 
maxdepth=range(1,10)
for i in maxdepth:
    #create a new model for given max_depth
    clf = tree.DecisionTreeClassifier(max_depth=i)
    #use the training set to train the tree
    clf = clf.fit(X_train, Y_train)
    Y_predicted=clf.predict(X_test)
    #calculate the performance metrics and ad assign them to array
    #to plot precision, recall, and f1 score agaist the maximum tree depth
    pre.append(precision_score(Y_test,Y_predicted,pos_label=0))
    recall.append(recall_score(Y_test,Y_predicted,pos_label=0))
    f1.append(f1_score(Y_test,Y_predicted,pos_label=0))
    print(i, pre,recall,f1)
 

#plot metrics
plt.figure(figsize=(6,8))
plt.plot(maxdepth,pre,label='Precision')    
plt.plot(maxdepth,recall,label="Recall") 
plt.plot(maxdepth,f1,label="F1") 
plt.legend()
plt.xticks(maxdepth)
plt.grid(color='b', axis='x', linestyle='-.', linewidth=1,alpha=0.2)
plt.xlabel('Maximum Depth of the Tree')
 

#plot the best tree
#find the index of maximum f1 score
index_maxf1 = np.argmax(f1)
#find the best maximum depth 
bestdepth=maxdepth[index_maxf1]
print('Optimized Depth of decision tree:',bestdepth)
# Out:
# 1 [0.8839103869653768] [0.37903930131004365] [0.530562347188264]
# 2 [0.8839103869653768, 0.8607427055702918] [0.37903930131004365, 0.5668122270742358] [0.530562347188264, 0.6835176408636124]
# 3 [0.8839103869653768, 0.8607427055702918, 0.8785471055618616] [0.37903930131004365, 0.5668122270742358, 0.6759825327510917] [0.530562347188264, 0.6835176408636124, 0.7640671273445212]
# 4 [0.8839103869653768, 0.8607427055702918, 0.8785471055618616, 0.8981264637002342] [0.37903930131004365, 0.5668122270742358, 0.6759825327510917, 0.6698689956331878] [0.530562347188264, 0.6835176408636124, 0.7640671273445212, 0.767383691845923]
# 5 [0.8839103869653768, 0.8607427055702918, 0.8785471055618616, 0.8981264637002342, 0.8970099667774086] [0.37903930131004365, 0.5668122270742358, 0.6759825327510917, 0.6698689956331878, 0.7074235807860262] [0.530562347188264, 0.6835176408636124, 0.7640671273445212, 0.767383691845923, 0.791015625]
# 6 [0.8839103869653768, 0.8607427055702918, 0.8785471055618616, 0.8981264637002342, 0.8970099667774086, 0.8772298006295908] [0.37903930131004365, 0.5668122270742358, 0.6759825327510917, 0.6698689956331878, 0.7074235807860262, 0.7301310043668122] [0.530562347188264, 0.6835176408636124, 0.7640671273445212, 0.767383691845923, 0.791015625, 0.7969494756911344]
# 7 [0.8839103869653768, 0.8607427055702918, 0.8785471055618616, 0.8981264637002342, 0.8970099667774086, 0.8772298006295908, 0.8820286659316428] [0.37903930131004365, 0.5668122270742358, 0.6759825327510917, 0.6698689956331878, 0.7074235807860262, 0.7301310043668122, 0.6986899563318777] [0.530562347188264, 0.6835176408636124, 0.7640671273445212, 0.767383691845923, 0.791015625, 0.7969494756911344, 0.7797270955165693]
# 8 [0.8839103869653768, 0.8607427055702918, 0.8785471055618616, 0.8981264637002342, 0.8970099667774086, 0.8772298006295908, 0.8820286659316428, 0.8811881188118812] [0.37903930131004365, 0.5668122270742358, 0.6759825327510917, 0.6698689956331878, 0.7074235807860262, 0.7301310043668122, 0.6986899563318777, 0.6995633187772926] [0.530562347188264, 0.6835176408636124, 0.7640671273445212, 0.767383691845923, 0.791015625, 0.7969494756911344, 0.7797270955165693, 0.7799415774099319]
# 9 [0.8839103869653768, 0.8607427055702918, 0.8785471055618616, 0.8981264637002342, 0.8970099667774086, 0.8772298006295908, 0.8820286659316428, 0.8811881188118812, 0.8425925925925926] [0.37903930131004365, 0.5668122270742358, 0.6759825327510917, 0.6698689956331878, 0.7074235807860262, 0.7301310043668122, 0.6986899563318777, 0.6995633187772926, 0.7152838427947599] [0.530562347188264, 0.6835176408636124, 0.7640671273445212, 0.767383691845923, 0.791015625, 0.7969494756911344, 0.7797270955165693, 0.7799415774099319, 0.7737364194615022]
# Optimized Depth of decision tree: 6

# %% [markdown]
# ##### Results
# maxdepth = 6 is a good balance, after that the F1 & Recall go down drastically.

# %% [markdown]
# # Justin, can you check the training/testing splits are done properly here.
# ### Fit & Plot AUC of a standard decision tree vs. a random forest
# The section below compares a random forest algorithm to a standard tree. Tests are done on both the testing set and training dataset. the AUC plots are plotted for tree vs. forest. Finaly, a confusion matrix is provided
#
# #### FIt & Plot of testing dataset

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_roc_curve

# Fit & Plot Decision Tree
clf = DecisionTreeClassifier(max_depth=6)
clf.fit(X_train, Y_train)
Y_test_predicted=clf.predict(X_test)
auc=roc_auc_score(Y_test, Y_test_predicted)
fig, ax = plt.subplots()
plot_roc_curve(clf, X_test, Y_test,name='Single Tree', lw=1, ax=ax)

# Fit & Plot Forest
rfclf=RandomForestClassifier(n_estimators=1000, max_depth=6,random_state=1, max_samples=400)
rfclf.fit(X_train, Y_train)
Y_test_predictedRF = rfclf.predict(X_test)
auc=roc_auc_score(Y_test, Y_test_predictedRF)

plot_roc_curve(rfclf, X_test, Y_test,name='Random Forest', lw=1, ax=ax)

plt.show()
# Out:
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##### Results:
#
#
# #### FIt & Plot of training dataset

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import plot_roc_curve

# Fit & Plot Decision Tree
clf = DecisionTreeClassifier(max_depth=6)
clf.fit(X_train, Y_train)
Y_train_predicted=clf.predict(X_train)
auc=roc_auc_score(Y_train, Y_train_predicted)
fig, ax = plt.subplots()
plot_roc_curve(clf, X_train, Y_train,name='Single Tree: Training Data', lw=1, ax=ax)

# Fit & Plot Forest
rfclf=RandomForestClassifier(n_estimators=1000, max_depth=6,random_state=1, max_samples=400)
rfclf.fit(X_train, Y_train)
Y_train_predictedRF = rfclf.predict(X_train)
auc=roc_auc_score(Y_train, Y_train_predictedRF)

plot_roc_curve(rfclf, X_train, Y_train,name='Random Forest: Training Data', lw=1, ax=ax)

plt.show()
# Out:
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##### Results:

# %% [markdown]
# Random forest provides a better ROC plot and is the better model but not by much. This makes sense as both algorithms will be better at predicting training data. There is less difference here between forest and single tree

# %% [markdown]
# ### Plot a confusion matrix for optimized Random Forest model

# %% [markdown]
# Plotting a confusion matrix for the optimized forest model.

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
cm = confusion_matrix(Y_test, Y_test_predictedRF)
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix: Testing')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix: Testing')

# %% [markdown]
# ##### Results:

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
cm = confusion_matrix(Y_train, Y_train_predictedRF)
sns.heatmap(cm, annot=True, fmt='g')
plt.xlabel('Predicted')
plt.ylabel('Truth')
plt.title('Confusion Matrix: Training')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix: Training')

# %% [markdown]
# ##### Results:

# %% [markdown]
# ### SVM algorithm
# SVM's are discriminative classification algorithm. It finds a equation that is able to discriminate data points of the features. It draws a line and one side of the line says it is a phishing email and the other tells us it is not a phishing email.

# %% [markdown]
# ##### Tuning and selecting the best C value for SVM algorithm on data
#
# large C = smaller error line boundries
#
# Smaller c = larger error line boundries
#
# Smaller C means better generalization
#
# Larger C value = beter performance on the training set
#
# We want our model to be able to generalize better so we will tune the algorithm for the smallest C possible keeping F1 robust.
#
# ##### Model testing for SVM algorithm will use gridseach on kfolds
# A gridsearch was used to test through 'c' values and kernel types. The tested parameters are stored and the best values are based on the F1 score.

# %%
####### Support Vector Classification on testing data #####

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

## Build a SVM model
Y=Y.to_numpy()
X=X.to_numpy()

from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.svm import SVC

########## Select best parameters and display the results ######### 

# This section of code will always be the same, only thing that will change will be the type
base_model=SVC()
kernel_values=['poly','rbf','linear','sigmoid']
c_values=np.linspace(0.1,100,10,endpoint=True)
kf=KFold(n_splits=5,shuffle=True)
tuned_parameters=[{'C':c_values,'kernel':kernel_values}]
scores=['precision','recall','f1','roc_auc']

from sklearn.model_selection import GridSearchCV

clf=GridSearchCV(estimator=base_model,
                 param_grid=tuned_parameters,
                 scoring=scores,
                 refit='f1',
                 cv=10,
                 verbose=3)

clf.fit(X,Y) # Look at variabe in 'best_params_' for best 
#'cv_results_' calculations for each fold
print(clf.best_estimator_) #Shows the best estimator & kernel
print(clf.best_params_) # Shows the best parameters, kerel and c-value
print(clf.cv_results_['params'])

# Take the results from (clf.cv_results_['params']) and create a dataframe to store results
df_results=pd.DataFrame(clf.cv_results_['params'])
df_results['f1']=clf.cv_results_['mean_test_f1']
df_results['auc']=clf.cv_results_['mean_test_roc_auc']
df_results['precision']=clf.cv_results_['mean_test_precision']

# Visualize df_results to find best kernel algorithm and c-value
# performance of f1 score
sns.lineplot(data=df_results,x='C',y='f1',hue='kernel')

# Look at precision instead of 'f1'
#sns.lineplot(data=df_results,x='C',y='precision',hue='kernel')
# Out:
# Fitting 10 folds for each of 40 candidates, totalling 400 fits
# [CV 1/10] END C=0.1, kernel=poly; f1: (test=0.826) precision: (test=0.751) recall: (test=0.918) roc_auc: (test=0.865) total time=   0.2s
# [CV 2/10] END C=0.1, kernel=poly; f1: (test=0.825) precision: (test=0.749) recall: (test=0.919) roc_auc: (test=0.834) total time=   0.2s
# [CV 3/10] END C=0.1, kernel=poly; f1: (test=0.805) precision: (test=0.760) recall: (test=0.855) roc_auc: (test=0.837) total time=   0.2s
# [CV 4/10] END C=0.1, kernel=poly; f1: (test=0.829) precision: (test=0.756) recall: (test=0.918) roc_auc: (test=0.854) total time=   0.2s
# [CV 5/10] END C=0.1, kernel=poly; f1: (test=0.833) precision: (test=0.746) recall: (test=0.944) roc_auc: (test=0.856) total time=   0.2s
# [CV 6/10] END C=0.1, kernel=poly; f1: (test=0.839) precision: (test=0.773) recall: (test=0.918) roc_auc: (test=0.889) total time=   0.2s
# [CV 7/10] END C=0.1, kernel=poly; f1: (test=0.776) precision: (test=0.696) recall: (test=0.876) roc_auc: (test=0.794) total time=   0.2s
# [CV 8/10] END C=0.1, kernel=poly; f1: (test=0.829) precision: (test=0.758) recall: (test=0.914) roc_auc: (test=0.853) total time=   0.2s
# [CV 9/10] END C=0.1, kernel=poly; f1: (test=0.827) precision: (test=0.764) recall: (test=0.901) roc_auc: (test=0.857) total time=   0.2s
# [CV 10/10] END C=0.1, kernel=poly; f1: (test=0.817) precision: (test=0.776) recall: (test=0.863) roc_auc: (test=0.856) total time=   0.2s
# [CV 1/10] END C=0.1, kernel=rbf; f1: (test=0.829) precision: (test=0.764) recall: (test=0.906) roc_auc: (test=0.888) total time=   0.2s
# [CV 2/10] END C=0.1, kernel=rbf; f1: (test=0.824) precision: (test=0.747) recall: (test=0.919) roc_auc: (test=0.855) total time=   0.2s
# [CV 3/10] END C=0.1, kernel=rbf; f1: (test=0.802) precision: (test=0.755) recall: (test=0.855) roc_auc: (test=0.856) total time=   0.2s
# [CV 4/10] END C=0.1, kernel=rbf; f1: (test=0.828) precision: (test=0.760) recall: (test=0.910) roc_auc: (test=0.875) total time=   0.2s
# [CV 5/10] END C=0.1, kernel=rbf; f1: (test=0.835) precision: (test=0.754) recall: (test=0.936) roc_auc: (test=0.872) total time=   0.2s
# [CV 6/10] END C=0.1, kernel=rbf; f1: (test=0.833) precision: (test=0.768) recall: (test=0.910) roc_auc: (test=0.891) total time=   0.2s
# [CV 7/10] END C=0.1, kernel=rbf; f1: (test=0.785) precision: (test=0.709) recall: (test=0.880) roc_auc: (test=0.830) total time=   0.2s
# [CV 8/10] END C=0.1, kernel=rbf; f1: (test=0.820) precision: (test=0.755) recall: (test=0.897) roc_auc: (test=0.857) total time=   0.2s
# [CV 9/10] END C=0.1, kernel=rbf; f1: (test=0.819) precision: (test=0.756) recall: (test=0.893) roc_auc: (test=0.876) total time=   0.2s
# [CV 10/10] END C=0.1, kernel=rbf; f1: (test=0.819) precision: (test=0.779) recall: (test=0.863) roc_auc: (test=0.859) total time=   0.2s
# [CV 1/10] END C=0.1, kernel=linear; f1: (test=0.792) precision: (test=0.689) recall: (test=0.931) roc_auc: (test=0.853) total time=   0.2s
# [CV 2/10] END C=0.1, kernel=linear; f1: (test=0.807) precision: (test=0.709) recall: (test=0.936) roc_auc: (test=0.821) total time=   0.2s
# [CV 3/10] END C=0.1, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.828) total time=   0.2s
# [CV 4/10] END C=0.1, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   0.2s
# [CV 5/10] END C=0.1, kernel=linear; f1: (test=0.796) precision: (test=0.679) recall: (test=0.961) roc_auc: (test=0.847) total time=   0.2s
# [CV 6/10] END C=0.1, kernel=linear; f1: (test=0.786) precision: (test=0.685) recall: (test=0.923) roc_auc: (test=0.861) total time=   0.2s
# [CV 7/10] END C=0.1, kernel=linear; f1: (test=0.758) precision: (test=0.654) recall: (test=0.901) roc_auc: (test=0.794) total time=   0.2s
# [CV 8/10] END C=0.1, kernel=linear; f1: (test=0.798) precision: (test=0.698) recall: (test=0.931) roc_auc: (test=0.844) total time=   0.2s
# [CV 9/10] END C=0.1, kernel=linear; f1: (test=0.799) precision: (test=0.701) recall: (test=0.927) roc_auc: (test=0.854) total time=   0.2s
# [CV 10/10] END C=0.1, kernel=linear; f1: (test=0.793) precision: (test=0.711) recall: (test=0.897) roc_auc: (test=0.836) total time=   0.2s
# [CV 1/10] END C=0.1, kernel=sigmoid; f1: (test=0.624) precision: (test=0.621) recall: (test=0.627) roc_auc: (test=0.682) total time=   0.3s
# [CV 2/10] END C=0.1, kernel=sigmoid; f1: (test=0.653) precision: (test=0.639) recall: (test=0.667) roc_auc: (test=0.710) total time=   0.3s
# [CV 3/10] END C=0.1, kernel=sigmoid; f1: (test=0.589) precision: (test=0.645) recall: (test=0.543) roc_auc: (test=0.694) total time=   0.3s
# [CV 4/10] END C=0.1, kernel=sigmoid; f1: (test=0.645) precision: (test=0.655) recall: (test=0.635) roc_auc: (test=0.712) total time=   0.3s
# [CV 5/10] END C=0.1, kernel=sigmoid; f1: (test=0.668) precision: (test=0.643) recall: (test=0.695) roc_auc: (test=0.725) total time=   0.3s
# [CV 6/10] END C=0.1, kernel=sigmoid; f1: (test=0.652) precision: (test=0.648) recall: (test=0.657) roc_auc: (test=0.704) total time=   0.3s
# [CV 7/10] END C=0.1, kernel=sigmoid; f1: (test=0.630) precision: (test=0.614) recall: (test=0.648) roc_auc: (test=0.654) total time=   0.3s
# [CV 8/10] END C=0.1, kernel=sigmoid; f1: (test=0.630) precision: (test=0.628) recall: (test=0.631) roc_auc: (test=0.682) total time=   0.3s
# [CV 9/10] END C=0.1, kernel=sigmoid; f1: (test=0.606) precision: (test=0.586) recall: (test=0.627) roc_auc: (test=0.655) total time=   0.3s
# [CV 10/10] END C=0.1, kernel=sigmoid; f1: (test=0.598) precision: (test=0.609) recall: (test=0.588) roc_auc: (test=0.665) total time=   0.3s
# [CV 1/10] END C=11.200000000000001, kernel=poly; f1: (test=0.826) precision: (test=0.772) recall: (test=0.888) roc_auc: (test=0.884) total time=   0.5s
# [CV 2/10] END C=11.200000000000001, kernel=poly; f1: (test=0.836) precision: (test=0.763) recall: (test=0.923) roc_auc: (test=0.853) total time=   0.6s
# [CV 3/10] END C=11.200000000000001, kernel=poly; f1: (test=0.806) precision: (test=0.752) recall: (test=0.868) roc_auc: (test=0.850) total time=   0.6s
# [CV 4/10] END C=11.200000000000001, kernel=poly; f1: (test=0.857) precision: (test=0.788) recall: (test=0.940) roc_auc: (test=0.892) total time=   0.5s
# [CV 5/10] END C=11.200000000000001, kernel=poly; f1: (test=0.837) precision: (test=0.757) recall: (test=0.936) roc_auc: (test=0.878) total time=   0.4s
# [CV 6/10] END C=11.200000000000001, kernel=poly; f1: (test=0.853) precision: (test=0.796) recall: (test=0.918) roc_auc: (test=0.900) total time=   0.5s
# [CV 7/10] END C=11.200000000000001, kernel=poly; f1: (test=0.794) precision: (test=0.715) recall: (test=0.893) roc_auc: (test=0.834) total time=   0.4s
# [CV 8/10] END C=11.200000000000001, kernel=poly; f1: (test=0.834) precision: (test=0.764) recall: (test=0.918) roc_auc: (test=0.870) total time=   0.5s
# [CV 9/10] END C=11.200000000000001, kernel=poly; f1: (test=0.838) precision: (test=0.770) recall: (test=0.918) roc_auc: (test=0.878) total time=   0.5s
# [CV 10/10] END C=11.200000000000001, kernel=poly; f1: (test=0.839) precision: (test=0.798) recall: (test=0.884) roc_auc: (test=0.874) total time=   0.4s
# [CV 1/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.841) precision: (test=0.773) recall: (test=0.923) roc_auc: (test=0.886) total time=   0.2s
# [CV 2/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.839) precision: (test=0.753) recall: (test=0.949) roc_auc: (test=0.872) total time=   0.2s
# [CV 3/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.827) precision: (test=0.766) recall: (test=0.897) roc_auc: (test=0.879) total time=   0.2s
# [CV 4/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.859) precision: (test=0.791) recall: (test=0.940) roc_auc: (test=0.884) total time=   0.2s
# [CV 5/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.848) precision: (test=0.761) recall: (test=0.957) roc_auc: (test=0.882) total time=   0.2s
# [CV 6/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.855) precision: (test=0.785) recall: (test=0.940) roc_auc: (test=0.900) total time=   0.2s
# [CV 7/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.806) precision: (test=0.718) recall: (test=0.918) roc_auc: (test=0.850) total time=   0.2s
# [CV 8/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.841) precision: (test=0.767) recall: (test=0.931) roc_auc: (test=0.879) total time=   0.2s
# [CV 9/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.842) precision: (test=0.771) recall: (test=0.927) roc_auc: (test=0.900) total time=   0.2s
# [CV 10/10] END C=11.200000000000001, kernel=rbf; f1: (test=0.846) precision: (test=0.791) recall: (test=0.910) roc_auc: (test=0.899) total time=   0.2s
# [CV 1/10] END C=11.200000000000001, kernel=linear; f1: (test=0.790) precision: (test=0.688) recall: (test=0.927) roc_auc: (test=0.853) total time=   0.5s
# [CV 2/10] END C=11.200000000000001, kernel=linear; f1: (test=0.804) precision: (test=0.708) recall: (test=0.932) roc_auc: (test=0.821) total time=   0.5s
# [CV 3/10] END C=11.200000000000001, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.829) total time=   0.5s
# [CV 4/10] END C=11.200000000000001, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   0.5s
# [CV 5/10] END C=11.200000000000001, kernel=linear; f1: (test=0.799) precision: (test=0.683) recall: (test=0.961) roc_auc: (test=0.846) total time=   0.5s
# [CV 6/10] END C=11.200000000000001, kernel=linear; f1: (test=0.788) precision: (test=0.687) recall: (test=0.923) roc_auc: (test=0.861) total time=   0.5s
# [CV 7/10] END C=11.200000000000001, kernel=linear; f1: (test=0.754) precision: (test=0.652) recall: (test=0.893) roc_auc: (test=0.795) total time=   0.4s
# [CV 8/10] END C=11.200000000000001, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.844) total time=   0.4s
# [CV 9/10] END C=11.200000000000001, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.855) total time=   0.5s
# [CV 10/10] END C=11.200000000000001, kernel=linear; f1: (test=0.795) precision: (test=0.713) recall: (test=0.897) roc_auc: (test=0.835) total time=   0.5s
# [CV 1/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.609) precision: (test=0.603) recall: (test=0.614) roc_auc: (test=0.648) total time=   0.2s
# [CV 2/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.614) precision: (test=0.609) recall: (test=0.620) roc_auc: (test=0.679) total time=   0.2s
# [CV 3/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.572) precision: (test=0.605) recall: (test=0.543) roc_auc: (test=0.662) total time=   0.2s
# [CV 4/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.623) precision: (test=0.633) recall: (test=0.614) roc_auc: (test=0.672) total time=   0.3s
# [CV 5/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.657) precision: (test=0.649) recall: (test=0.665) roc_auc: (test=0.691) total time=   0.2s
# [CV 6/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.623) precision: (test=0.619) recall: (test=0.627) roc_auc: (test=0.670) total time=   0.2s
# [CV 7/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.603) precision: (test=0.606) recall: (test=0.601) roc_auc: (test=0.622) total time=   0.2s
# [CV 8/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.618) precision: (test=0.618) recall: (test=0.618) roc_auc: (test=0.651) total time=   0.2s
# [CV 9/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.581) precision: (test=0.579) recall: (test=0.584) roc_auc: (test=0.618) total time=   0.2s
# [CV 10/10] END C=11.200000000000001, kernel=sigmoid; f1: (test=0.629) precision: (test=0.640) recall: (test=0.618) roc_auc: (test=0.690) total time=   0.2s
# [CV 1/10] END C=22.300000000000004, kernel=poly; f1: (test=0.835) precision: (test=0.778) recall: (test=0.901) roc_auc: (test=0.885) total time=   0.8s
# [CV 2/10] END C=22.300000000000004, kernel=poly; f1: (test=0.835) precision: (test=0.765) recall: (test=0.919) roc_auc: (test=0.853) total time=   0.7s
# [CV 3/10] END C=22.300000000000004, kernel=poly; f1: (test=0.807) precision: (test=0.755) recall: (test=0.868) roc_auc: (test=0.849) total time=   0.9s
# [CV 4/10] END C=22.300000000000004, kernel=poly; f1: (test=0.860) precision: (test=0.786) recall: (test=0.948) roc_auc: (test=0.893) total time=   1.2s
# [CV 5/10] END C=22.300000000000004, kernel=poly; f1: (test=0.842) precision: (test=0.763) recall: (test=0.940) roc_auc: (test=0.880) total time=   0.5s
# [CV 6/10] END C=22.300000000000004, kernel=poly; f1: (test=0.849) precision: (test=0.790) recall: (test=0.918) roc_auc: (test=0.900) total time=   0.8s
# [CV 7/10] END C=22.300000000000004, kernel=poly; f1: (test=0.794) precision: (test=0.715) recall: (test=0.893) roc_auc: (test=0.836) total time=   0.5s
# [CV 8/10] END C=22.300000000000004, kernel=poly; f1: (test=0.834) precision: (test=0.766) recall: (test=0.914) roc_auc: (test=0.868) total time=   0.7s
# [CV 9/10] END C=22.300000000000004, kernel=poly; f1: (test=0.840) precision: (test=0.771) recall: (test=0.923) roc_auc: (test=0.880) total time=   0.9s
# [CV 10/10] END C=22.300000000000004, kernel=poly; f1: (test=0.844) precision: (test=0.798) recall: (test=0.897) roc_auc: (test=0.876) total time=   0.7s
# [CV 1/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.846) precision: (test=0.782) recall: (test=0.923) roc_auc: (test=0.883) total time=   0.2s
# [CV 2/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.843) precision: (test=0.758) recall: (test=0.949) roc_auc: (test=0.871) total time=   0.2s
# [CV 3/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.824) precision: (test=0.768) recall: (test=0.889) roc_auc: (test=0.879) total time=   0.2s
# [CV 4/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.859) precision: (test=0.791) recall: (test=0.940) roc_auc: (test=0.883) total time=   0.2s
# [CV 5/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.858) precision: (test=0.775) recall: (test=0.961) roc_auc: (test=0.884) total time=   0.3s
# [CV 6/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.857) precision: (test=0.788) recall: (test=0.940) roc_auc: (test=0.899) total time=   0.2s
# [CV 7/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.810) precision: (test=0.721) recall: (test=0.923) roc_auc: (test=0.849) total time=   0.2s
# [CV 8/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.837) precision: (test=0.763) recall: (test=0.927) roc_auc: (test=0.882) total time=   0.2s
# [CV 9/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.832) precision: (test=0.763) recall: (test=0.914) roc_auc: (test=0.898) total time=   0.2s
# [CV 10/10] END C=22.300000000000004, kernel=rbf; f1: (test=0.848) precision: (test=0.794) recall: (test=0.910) roc_auc: (test=0.901) total time=   0.2s
# [CV 1/10] END C=22.300000000000004, kernel=linear; f1: (test=0.790) precision: (test=0.688) recall: (test=0.927) roc_auc: (test=0.853) total time=   0.7s
# [CV 2/10] END C=22.300000000000004, kernel=linear; f1: (test=0.804) precision: (test=0.708) recall: (test=0.932) roc_auc: (test=0.821) total time=   0.7s
# [CV 3/10] END C=22.300000000000004, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.828) total time=   0.7s
# [CV 4/10] END C=22.300000000000004, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   0.7s
# [CV 5/10] END C=22.300000000000004, kernel=linear; f1: (test=0.799) precision: (test=0.683) recall: (test=0.961) roc_auc: (test=0.846) total time=   0.7s
# [CV 6/10] END C=22.300000000000004, kernel=linear; f1: (test=0.788) precision: (test=0.687) recall: (test=0.923) roc_auc: (test=0.861) total time=   0.8s
# [CV 7/10] END C=22.300000000000004, kernel=linear; f1: (test=0.754) precision: (test=0.652) recall: (test=0.893) roc_auc: (test=0.795) total time=   0.7s
# [CV 8/10] END C=22.300000000000004, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.844) total time=   0.7s
# [CV 9/10] END C=22.300000000000004, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.855) total time=   0.7s
# [CV 10/10] END C=22.300000000000004, kernel=linear; f1: (test=0.795) precision: (test=0.713) recall: (test=0.897) roc_auc: (test=0.835) total time=   0.6s
# [CV 1/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.611) precision: (test=0.609) recall: (test=0.614) roc_auc: (test=0.648) total time=   0.3s
# [CV 2/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.620) precision: (test=0.613) recall: (test=0.628) roc_auc: (test=0.679) total time=   0.2s
# [CV 3/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.572) precision: (test=0.605) recall: (test=0.543) roc_auc: (test=0.662) total time=   0.2s
# [CV 4/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.626) precision: (test=0.638) recall: (test=0.614) roc_auc: (test=0.672) total time=   0.2s
# [CV 5/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.653) precision: (test=0.644) recall: (test=0.661) roc_auc: (test=0.692) total time=   0.2s
# [CV 6/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.631) precision: (test=0.623) recall: (test=0.639) roc_auc: (test=0.671) total time=   0.2s
# [CV 7/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.603) precision: (test=0.606) recall: (test=0.601) roc_auc: (test=0.623) total time=   0.2s
# [CV 8/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.618) precision: (test=0.618) recall: (test=0.618) roc_auc: (test=0.651) total time=   0.2s
# [CV 9/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.574) precision: (test=0.573) recall: (test=0.575) roc_auc: (test=0.617) total time=   0.2s
# [CV 10/10] END C=22.300000000000004, kernel=sigmoid; f1: (test=0.626) precision: (test=0.638) recall: (test=0.614) roc_auc: (test=0.690) total time=   0.2s
# [CV 1/10] END C=33.400000000000006, kernel=poly; f1: (test=0.835) precision: (test=0.778) recall: (test=0.901) roc_auc: (test=0.885) total time=   1.1s
# [CV 2/10] END C=33.400000000000006, kernel=poly; f1: (test=0.841) precision: (test=0.763) recall: (test=0.936) roc_auc: (test=0.854) total time=   1.0s
# [CV 3/10] END C=33.400000000000006, kernel=poly; f1: (test=0.804) precision: (test=0.749) recall: (test=0.868) roc_auc: (test=0.848) total time=   1.1s
# [CV 4/10] END C=33.400000000000006, kernel=poly; f1: (test=0.860) precision: (test=0.786) recall: (test=0.948) roc_auc: (test=0.893) total time=   1.4s
# [CV 5/10] END C=33.400000000000006, kernel=poly; f1: (test=0.839) precision: (test=0.758) recall: (test=0.940) roc_auc: (test=0.879) total time=   1.0s
# [CV 6/10] END C=33.400000000000006, kernel=poly; f1: (test=0.851) precision: (test=0.793) recall: (test=0.918) roc_auc: (test=0.899) total time=   1.0s
# [CV 7/10] END C=33.400000000000006, kernel=poly; f1: (test=0.801) precision: (test=0.718) recall: (test=0.906) roc_auc: (test=0.836) total time=   0.9s
# [CV 8/10] END C=33.400000000000006, kernel=poly; f1: (test=0.834) precision: (test=0.766) recall: (test=0.914) roc_auc: (test=0.868) total time=   1.1s
# [CV 9/10] END C=33.400000000000006, kernel=poly; f1: (test=0.840) precision: (test=0.771) recall: (test=0.923) roc_auc: (test=0.883) total time=   1.0s
# [CV 10/10] END C=33.400000000000006, kernel=poly; f1: (test=0.847) precision: (test=0.798) recall: (test=0.901) roc_auc: (test=0.877) total time=   0.7s
# [CV 1/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.848) precision: (test=0.787) recall: (test=0.918) roc_auc: (test=0.882) total time=   0.3s
# [CV 2/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.846) precision: (test=0.763) recall: (test=0.949) roc_auc: (test=0.871) total time=   0.3s
# [CV 3/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.828) precision: (test=0.771) recall: (test=0.893) roc_auc: (test=0.879) total time=   0.3s
# [CV 4/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.861) precision: (test=0.791) recall: (test=0.944) roc_auc: (test=0.880) total time=   0.3s
# [CV 5/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.860) precision: (test=0.776) recall: (test=0.966) roc_auc: (test=0.886) total time=   0.3s
# [CV 6/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.859) precision: (test=0.791) recall: (test=0.940) roc_auc: (test=0.901) total time=   0.3s
# [CV 7/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.808) precision: (test=0.719) recall: (test=0.923) roc_auc: (test=0.851) total time=   0.3s
# [CV 8/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.838) precision: (test=0.761) recall: (test=0.931) roc_auc: (test=0.880) total time=   0.3s
# [CV 9/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.835) precision: (test=0.769) recall: (test=0.914) roc_auc: (test=0.899) total time=   0.3s
# [CV 10/10] END C=33.400000000000006, kernel=rbf; f1: (test=0.845) precision: (test=0.795) recall: (test=0.901) roc_auc: (test=0.901) total time=   0.3s
# [CV 1/10] END C=33.400000000000006, kernel=linear; f1: (test=0.790) precision: (test=0.688) recall: (test=0.927) roc_auc: (test=0.853) total time=   0.9s
# [CV 2/10] END C=33.400000000000006, kernel=linear; f1: (test=0.804) precision: (test=0.708) recall: (test=0.932) roc_auc: (test=0.821) total time=   0.9s
# [CV 3/10] END C=33.400000000000006, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.828) total time=   0.9s
# [CV 4/10] END C=33.400000000000006, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   1.0s
# [CV 5/10] END C=33.400000000000006, kernel=linear; f1: (test=0.799) precision: (test=0.683) recall: (test=0.961) roc_auc: (test=0.846) total time=   0.9s
# [CV 6/10] END C=33.400000000000006, kernel=linear; f1: (test=0.788) precision: (test=0.687) recall: (test=0.923) roc_auc: (test=0.861) total time=   0.9s
# [CV 7/10] END C=33.400000000000006, kernel=linear; f1: (test=0.754) precision: (test=0.652) recall: (test=0.893) roc_auc: (test=0.795) total time=   0.8s
# [CV 8/10] END C=33.400000000000006, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.844) total time=   0.9s
# [CV 9/10] END C=33.400000000000006, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.855) total time=   0.9s
# [CV 10/10] END C=33.400000000000006, kernel=linear; f1: (test=0.795) precision: (test=0.713) recall: (test=0.897) roc_auc: (test=0.835) total time=   0.9s
# [CV 1/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.657) precision: (test=0.661) recall: (test=0.652) roc_auc: (test=0.678) total time=   0.2s
# [CV 2/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.614) precision: (test=0.609) recall: (test=0.620) roc_auc: (test=0.679) total time=   0.2s
# [CV 3/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.572) precision: (test=0.605) recall: (test=0.543) roc_auc: (test=0.662) total time=   0.2s
# [CV 4/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.647) precision: (test=0.637) recall: (test=0.657) roc_auc: (test=0.688) total time=   0.2s
# [CV 5/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.653) precision: (test=0.644) recall: (test=0.661) roc_auc: (test=0.692) total time=   0.2s
# [CV 6/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.631) precision: (test=0.623) recall: (test=0.639) roc_auc: (test=0.671) total time=   0.2s
# [CV 7/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.603) precision: (test=0.606) recall: (test=0.601) roc_auc: (test=0.623) total time=   0.2s
# [CV 8/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.618) precision: (test=0.618) recall: (test=0.618) roc_auc: (test=0.650) total time=   0.2s
# [CV 9/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.574) precision: (test=0.573) recall: (test=0.575) roc_auc: (test=0.617) total time=   0.2s
# [CV 10/10] END C=33.400000000000006, kernel=sigmoid; f1: (test=0.626) precision: (test=0.638) recall: (test=0.614) roc_auc: (test=0.690) total time=   0.2s
# [CV 1/10] END C=44.50000000000001, kernel=poly; f1: (test=0.835) precision: (test=0.778) recall: (test=0.901) roc_auc: (test=0.884) total time=   1.0s
# [CV 2/10] END C=44.50000000000001, kernel=poly; f1: (test=0.841) precision: (test=0.761) recall: (test=0.940) roc_auc: (test=0.855) total time=   1.2s
# [CV 3/10] END C=44.50000000000001, kernel=poly; f1: (test=0.809) precision: (test=0.751) recall: (test=0.876) roc_auc: (test=0.848) total time=   1.7s
# [CV 4/10] END C=44.50000000000001, kernel=poly; f1: (test=0.860) precision: (test=0.786) recall: (test=0.948) roc_auc: (test=0.892) total time=   1.5s
# [CV 5/10] END C=44.50000000000001, kernel=poly; f1: (test=0.841) precision: (test=0.760) recall: (test=0.940) roc_auc: (test=0.880) total time=   1.5s
# [CV 6/10] END C=44.50000000000001, kernel=poly; f1: (test=0.849) precision: (test=0.790) recall: (test=0.918) roc_auc: (test=0.898) total time=   1.2s
# [CV 7/10] END C=44.50000000000001, kernel=poly; f1: (test=0.797) precision: (test=0.714) recall: (test=0.901) roc_auc: (test=0.838) total time=   0.8s
# [CV 8/10] END C=44.50000000000001, kernel=poly; f1: (test=0.834) precision: (test=0.766) recall: (test=0.914) roc_auc: (test=0.868) total time=   1.6s
# [CV 9/10] END C=44.50000000000001, kernel=poly; f1: (test=0.845) precision: (test=0.777) recall: (test=0.927) roc_auc: (test=0.884) total time=   1.5s
# [CV 10/10] END C=44.50000000000001, kernel=poly; f1: (test=0.842) precision: (test=0.797) recall: (test=0.893) roc_auc: (test=0.877) total time=   1.0s
# [CV 1/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.848) precision: (test=0.787) recall: (test=0.918) roc_auc: (test=0.885) total time=   0.3s
# [CV 2/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.843) precision: (test=0.758) recall: (test=0.949) roc_auc: (test=0.871) total time=   0.3s
# [CV 3/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.828) precision: (test=0.771) recall: (test=0.893) roc_auc: (test=0.878) total time=   0.3s
# [CV 4/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.861) precision: (test=0.791) recall: (test=0.944) roc_auc: (test=0.881) total time=   0.3s
# [CV 5/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.862) precision: (test=0.779) recall: (test=0.966) roc_auc: (test=0.885) total time=   0.3s
# [CV 6/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.854) precision: (test=0.789) recall: (test=0.931) roc_auc: (test=0.903) total time=   0.3s
# [CV 7/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.810) precision: (test=0.721) recall: (test=0.923) roc_auc: (test=0.850) total time=   0.3s
# [CV 8/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.839) precision: (test=0.764) recall: (test=0.931) roc_auc: (test=0.878) total time=   0.3s
# [CV 9/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.829) precision: (test=0.758) recall: (test=0.914) roc_auc: (test=0.898) total time=   0.3s
# [CV 10/10] END C=44.50000000000001, kernel=rbf; f1: (test=0.847) precision: (test=0.796) recall: (test=0.906) roc_auc: (test=0.902) total time=   0.3s
# [CV 1/10] END C=44.50000000000001, kernel=linear; f1: (test=0.790) precision: (test=0.688) recall: (test=0.927) roc_auc: (test=0.853) total time=   1.1s
# [CV 2/10] END C=44.50000000000001, kernel=linear; f1: (test=0.804) precision: (test=0.708) recall: (test=0.932) roc_auc: (test=0.821) total time=   1.2s
# [CV 3/10] END C=44.50000000000001, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.828) total time=   1.1s
# [CV 4/10] END C=44.50000000000001, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   1.1s
# [CV 5/10] END C=44.50000000000001, kernel=linear; f1: (test=0.799) precision: (test=0.683) recall: (test=0.961) roc_auc: (test=0.846) total time=   1.1s
# [CV 6/10] END C=44.50000000000001, kernel=linear; f1: (test=0.788) precision: (test=0.687) recall: (test=0.923) roc_auc: (test=0.861) total time=   1.1s
# [CV 7/10] END C=44.50000000000001, kernel=linear; f1: (test=0.754) precision: (test=0.652) recall: (test=0.893) roc_auc: (test=0.795) total time=   1.1s
# [CV 8/10] END C=44.50000000000001, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.844) total time=   1.1s
# [CV 9/10] END C=44.50000000000001, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.855) total time=   1.1s
# [CV 10/10] END C=44.50000000000001, kernel=linear; f1: (test=0.795) precision: (test=0.713) recall: (test=0.897) roc_auc: (test=0.835) total time=   1.0s
# [CV 1/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.657) precision: (test=0.661) recall: (test=0.652) roc_auc: (test=0.678) total time=   0.2s
# [CV 2/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.614) precision: (test=0.609) recall: (test=0.620) roc_auc: (test=0.679) total time=   0.2s
# [CV 3/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.572) precision: (test=0.605) recall: (test=0.543) roc_auc: (test=0.662) total time=   0.2s
# [CV 4/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.647) precision: (test=0.637) recall: (test=0.657) roc_auc: (test=0.688) total time=   0.2s
# [CV 5/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.653) precision: (test=0.644) recall: (test=0.661) roc_auc: (test=0.692) total time=   0.2s
# [CV 6/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.631) precision: (test=0.623) recall: (test=0.639) roc_auc: (test=0.671) total time=   0.2s
# [CV 7/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.603) precision: (test=0.606) recall: (test=0.601) roc_auc: (test=0.623) total time=   0.2s
# [CV 8/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.618) precision: (test=0.618) recall: (test=0.618) roc_auc: (test=0.650) total time=   0.2s
# [CV 9/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.574) precision: (test=0.573) recall: (test=0.575) roc_auc: (test=0.617) total time=   0.2s
# [CV 10/10] END C=44.50000000000001, kernel=sigmoid; f1: (test=0.629) precision: (test=0.640) recall: (test=0.618) roc_auc: (test=0.690) total time=   0.2s
# [CV 1/10] END C=55.60000000000001, kernel=poly; f1: (test=0.834) precision: (test=0.780) recall: (test=0.897) roc_auc: (test=0.884) total time=   1.4s
# [CV 2/10] END C=55.60000000000001, kernel=poly; f1: (test=0.841) precision: (test=0.761) recall: (test=0.940) roc_auc: (test=0.854) total time=   1.5s
# [CV 3/10] END C=55.60000000000001, kernel=poly; f1: (test=0.810) precision: (test=0.754) recall: (test=0.876) roc_auc: (test=0.848) total time=   1.7s
# [CV 4/10] END C=55.60000000000001, kernel=poly; f1: (test=0.860) precision: (test=0.786) recall: (test=0.948) roc_auc: (test=0.891) total time=   2.2s
# [CV 5/10] END C=55.60000000000001, kernel=poly; f1: (test=0.842) precision: (test=0.763) recall: (test=0.940) roc_auc: (test=0.880) total time=   1.3s
# [CV 6/10] END C=55.60000000000001, kernel=poly; f1: (test=0.851) precision: (test=0.790) recall: (test=0.923) roc_auc: (test=0.897) total time=   1.8s
# [CV 7/10] END C=55.60000000000001, kernel=poly; f1: (test=0.798) precision: (test=0.717) recall: (test=0.901) roc_auc: (test=0.839) total time=   1.3s
# [CV 8/10] END C=55.60000000000001, kernel=poly; f1: (test=0.834) precision: (test=0.766) recall: (test=0.914) roc_auc: (test=0.867) total time=   1.6s
# [CV 9/10] END C=55.60000000000001, kernel=poly; f1: (test=0.845) precision: (test=0.777) recall: (test=0.927) roc_auc: (test=0.883) total time=   2.0s
# [CV 10/10] END C=55.60000000000001, kernel=poly; f1: (test=0.844) precision: (test=0.798) recall: (test=0.897) roc_auc: (test=0.877) total time=   1.4s
# [CV 1/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.848) precision: (test=0.787) recall: (test=0.918) roc_auc: (test=0.885) total time=   0.3s
# [CV 2/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.846) precision: (test=0.763) recall: (test=0.949) roc_auc: (test=0.872) total time=   0.3s
# [CV 3/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.826) precision: (test=0.768) recall: (test=0.893) roc_auc: (test=0.878) total time=   0.3s
# [CV 4/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.861) precision: (test=0.791) recall: (test=0.944) roc_auc: (test=0.882) total time=   0.3s
# [CV 5/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.862) precision: (test=0.779) recall: (test=0.966) roc_auc: (test=0.885) total time=   0.3s
# [CV 6/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.859) precision: (test=0.791) recall: (test=0.940) roc_auc: (test=0.905) total time=   0.3s
# [CV 7/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.814) precision: (test=0.725) recall: (test=0.927) roc_auc: (test=0.852) total time=   0.3s
# [CV 8/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.841) precision: (test=0.767) recall: (test=0.931) roc_auc: (test=0.878) total time=   0.3s
# [CV 9/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.832) precision: (test=0.763) recall: (test=0.914) roc_auc: (test=0.897) total time=   0.3s
# [CV 10/10] END C=55.60000000000001, kernel=rbf; f1: (test=0.845) precision: (test=0.795) recall: (test=0.901) roc_auc: (test=0.902) total time=   0.3s
# [CV 1/10] END C=55.60000000000001, kernel=linear; f1: (test=0.790) precision: (test=0.688) recall: (test=0.927) roc_auc: (test=0.853) total time=   1.5s
# [CV 2/10] END C=55.60000000000001, kernel=linear; f1: (test=0.804) precision: (test=0.708) recall: (test=0.932) roc_auc: (test=0.821) total time=   1.3s
# [CV 3/10] END C=55.60000000000001, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.829) total time=   1.3s
# [CV 4/10] END C=55.60000000000001, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   1.4s
# [CV 5/10] END C=55.60000000000001, kernel=linear; f1: (test=0.799) precision: (test=0.683) recall: (test=0.961) roc_auc: (test=0.846) total time=   1.3s
# [CV 6/10] END C=55.60000000000001, kernel=linear; f1: (test=0.788) precision: (test=0.687) recall: (test=0.923) roc_auc: (test=0.861) total time=   1.4s
# [CV 7/10] END C=55.60000000000001, kernel=linear; f1: (test=0.754) precision: (test=0.652) recall: (test=0.893) roc_auc: (test=0.795) total time=   1.3s
# [CV 8/10] END C=55.60000000000001, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.844) total time=   1.3s
# [CV 9/10] END C=55.60000000000001, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.855) total time=   1.3s
# [CV 10/10] END C=55.60000000000001, kernel=linear; f1: (test=0.795) precision: (test=0.713) recall: (test=0.897) roc_auc: (test=0.835) total time=   1.3s
# [CV 1/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.657) precision: (test=0.661) recall: (test=0.652) roc_auc: (test=0.678) total time=   0.2s
# [CV 2/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.614) precision: (test=0.609) recall: (test=0.620) roc_auc: (test=0.678) total time=   0.2s
# [CV 3/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.572) precision: (test=0.605) recall: (test=0.543) roc_auc: (test=0.662) total time=   0.2s
# [CV 4/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.623) precision: (test=0.633) recall: (test=0.614) roc_auc: (test=0.672) total time=   0.3s
# [CV 5/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.653) precision: (test=0.644) recall: (test=0.661) roc_auc: (test=0.692) total time=   0.2s
# [CV 6/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.631) precision: (test=0.623) recall: (test=0.639) roc_auc: (test=0.671) total time=   0.2s
# [CV 7/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.603) precision: (test=0.606) recall: (test=0.601) roc_auc: (test=0.623) total time=   0.2s
# [CV 8/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.619) precision: (test=0.621) recall: (test=0.618) roc_auc: (test=0.651) total time=   0.2s
# [CV 9/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.574) precision: (test=0.573) recall: (test=0.575) roc_auc: (test=0.617) total time=   0.2s
# [CV 10/10] END C=55.60000000000001, kernel=sigmoid; f1: (test=0.629) precision: (test=0.640) recall: (test=0.618) roc_auc: (test=0.690) total time=   0.2s
# [CV 1/10] END C=66.7, kernel=poly; f1: (test=0.834) precision: (test=0.780) recall: (test=0.897) roc_auc: (test=0.883) total time=   1.5s
# [CV 2/10] END C=66.7, kernel=poly; f1: (test=0.835) precision: (test=0.757) recall: (test=0.932) roc_auc: (test=0.853) total time=   1.7s
# [CV 3/10] END C=66.7, kernel=poly; f1: (test=0.811) precision: (test=0.752) recall: (test=0.880) roc_auc: (test=0.848) total time=   1.5s
# [CV 4/10] END C=66.7, kernel=poly; f1: (test=0.860) precision: (test=0.786) recall: (test=0.948) roc_auc: (test=0.892) total time=   2.1s
# [CV 5/10] END C=66.7, kernel=poly; f1: (test=0.842) precision: (test=0.763) recall: (test=0.940) roc_auc: (test=0.879) total time=   1.6s
# [CV 6/10] END C=66.7, kernel=poly; f1: (test=0.851) precision: (test=0.790) recall: (test=0.923) roc_auc: (test=0.896) total time=   1.9s
# [CV 7/10] END C=66.7, kernel=poly; f1: (test=0.798) precision: (test=0.717) recall: (test=0.901) roc_auc: (test=0.840) total time=   1.1s
# [CV 8/10] END C=66.7, kernel=poly; f1: (test=0.834) precision: (test=0.766) recall: (test=0.914) roc_auc: (test=0.867) total time=   1.8s
# [CV 9/10] END C=66.7, kernel=poly; f1: (test=0.844) precision: (test=0.774) recall: (test=0.927) roc_auc: (test=0.883) total time=   2.0s
# [CV 10/10] END C=66.7, kernel=poly; f1: (test=0.844) precision: (test=0.798) recall: (test=0.897) roc_auc: (test=0.877) total time=   1.5s
# [CV 1/10] END C=66.7, kernel=rbf; f1: (test=0.845) precision: (test=0.786) recall: (test=0.914) roc_auc: (test=0.887) total time=   0.3s
# [CV 2/10] END C=66.7, kernel=rbf; f1: (test=0.846) precision: (test=0.763) recall: (test=0.949) roc_auc: (test=0.872) total time=   0.3s
# [CV 3/10] END C=66.7, kernel=rbf; f1: (test=0.826) precision: (test=0.768) recall: (test=0.893) roc_auc: (test=0.877) total time=   0.3s
# [CV 4/10] END C=66.7, kernel=rbf; f1: (test=0.861) precision: (test=0.791) recall: (test=0.944) roc_auc: (test=0.884) total time=   0.3s
# [CV 5/10] END C=66.7, kernel=rbf; f1: (test=0.864) precision: (test=0.781) recall: (test=0.966) roc_auc: (test=0.886) total time=   0.3s
# [CV 6/10] END C=66.7, kernel=rbf; f1: (test=0.857) precision: (test=0.788) recall: (test=0.940) roc_auc: (test=0.904) total time=   0.3s
# [CV 7/10] END C=66.7, kernel=rbf; f1: (test=0.814) precision: (test=0.723) recall: (test=0.931) roc_auc: (test=0.852) total time=   0.3s
# [CV 8/10] END C=66.7, kernel=rbf; f1: (test=0.837) precision: (test=0.765) recall: (test=0.923) roc_auc: (test=0.878) total time=   0.3s
# [CV 9/10] END C=66.7, kernel=rbf; f1: (test=0.834) precision: (test=0.766) recall: (test=0.914) roc_auc: (test=0.897) total time=   0.3s
# [CV 10/10] END C=66.7, kernel=rbf; f1: (test=0.847) precision: (test=0.796) recall: (test=0.906) roc_auc: (test=0.902) total time=   0.3s
# [CV 1/10] END C=66.7, kernel=linear; f1: (test=0.790) precision: (test=0.688) recall: (test=0.927) roc_auc: (test=0.853) total time=   1.6s
# [CV 2/10] END C=66.7, kernel=linear; f1: (test=0.804) precision: (test=0.708) recall: (test=0.932) roc_auc: (test=0.821) total time=   1.5s
# [CV 3/10] END C=66.7, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.829) total time=   1.5s
# [CV 4/10] END C=66.7, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   1.5s
# [CV 5/10] END C=66.7, kernel=linear; f1: (test=0.799) precision: (test=0.683) recall: (test=0.961) roc_auc: (test=0.846) total time=   1.6s
# [CV 6/10] END C=66.7, kernel=linear; f1: (test=0.788) precision: (test=0.687) recall: (test=0.923) roc_auc: (test=0.861) total time=   1.6s
# [CV 7/10] END C=66.7, kernel=linear; f1: (test=0.754) precision: (test=0.652) recall: (test=0.893) roc_auc: (test=0.795) total time=   1.4s
# [CV 8/10] END C=66.7, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.844) total time=   1.5s
# [CV 9/10] END C=66.7, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.855) total time=   1.5s
# [CV 10/10] END C=66.7, kernel=linear; f1: (test=0.795) precision: (test=0.713) recall: (test=0.897) roc_auc: (test=0.835) total time=   1.5s
# [CV 1/10] END C=66.7, kernel=sigmoid; f1: (test=0.611) precision: (test=0.609) recall: (test=0.614) roc_auc: (test=0.647) total time=   0.2s
# [CV 2/10] END C=66.7, kernel=sigmoid; f1: (test=0.614) precision: (test=0.609) recall: (test=0.620) roc_auc: (test=0.679) total time=   0.2s
# [CV 3/10] END C=66.7, kernel=sigmoid; f1: (test=0.569) precision: (test=0.603) recall: (test=0.538) roc_auc: (test=0.662) total time=   0.2s
# [CV 4/10] END C=66.7, kernel=sigmoid; f1: (test=0.623) precision: (test=0.633) recall: (test=0.614) roc_auc: (test=0.672) total time=   0.3s
# [CV 5/10] END C=66.7, kernel=sigmoid; f1: (test=0.653) precision: (test=0.644) recall: (test=0.661) roc_auc: (test=0.692) total time=   0.2s
# [CV 6/10] END C=66.7, kernel=sigmoid; f1: (test=0.630) precision: (test=0.621) recall: (test=0.639) roc_auc: (test=0.671) total time=   0.2s
# [CV 7/10] END C=66.7, kernel=sigmoid; f1: (test=0.603) precision: (test=0.606) recall: (test=0.601) roc_auc: (test=0.623) total time=   0.2s
# [CV 8/10] END C=66.7, kernel=sigmoid; f1: (test=0.619) precision: (test=0.621) recall: (test=0.618) roc_auc: (test=0.650) total time=   0.2s
# [CV 9/10] END C=66.7, kernel=sigmoid; f1: (test=0.574) precision: (test=0.573) recall: (test=0.575) roc_auc: (test=0.617) total time=   0.2s
# [CV 10/10] END C=66.7, kernel=sigmoid; f1: (test=0.629) precision: (test=0.640) recall: (test=0.618) roc_auc: (test=0.690) total time=   0.2s
# [CV 1/10] END C=77.80000000000001, kernel=poly; f1: (test=0.836) precision: (test=0.783) recall: (test=0.897) roc_auc: (test=0.882) total time=   1.9s
# [CV 2/10] END C=77.80000000000001, kernel=poly; f1: (test=0.834) precision: (test=0.754) recall: (test=0.932) roc_auc: (test=0.854) total time=   2.5s
# [CV 3/10] END C=77.80000000000001, kernel=poly; f1: (test=0.814) precision: (test=0.757) recall: (test=0.880) roc_auc: (test=0.848) total time=   2.0s
# [CV 4/10] END C=77.80000000000001, kernel=poly; f1: (test=0.860) precision: (test=0.786) recall: (test=0.948) roc_auc: (test=0.891) total time=   2.7s
# [CV 5/10] END C=77.80000000000001, kernel=poly; f1: (test=0.842) precision: (test=0.763) recall: (test=0.940) roc_auc: (test=0.879) total time=   1.6s
# [CV 6/10] END C=77.80000000000001, kernel=poly; f1: (test=0.848) precision: (test=0.785) recall: (test=0.923) roc_auc: (test=0.896) total time=   1.9s
# [CV 7/10] END C=77.80000000000001, kernel=poly; f1: (test=0.798) precision: (test=0.717) recall: (test=0.901) roc_auc: (test=0.839) total time=   1.2s
# [CV 8/10] END C=77.80000000000001, kernel=poly; f1: (test=0.832) precision: (test=0.763) recall: (test=0.914) roc_auc: (test=0.867) total time=   1.9s
# [CV 9/10] END C=77.80000000000001, kernel=poly; f1: (test=0.845) precision: (test=0.777) recall: (test=0.927) roc_auc: (test=0.883) total time=   1.7s
# [CV 10/10] END C=77.80000000000001, kernel=poly; f1: (test=0.844) precision: (test=0.798) recall: (test=0.897) roc_auc: (test=0.877) total time=   1.6s
# [CV 1/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.845) precision: (test=0.786) recall: (test=0.914) roc_auc: (test=0.888) total time=   0.3s
# [CV 2/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.846) precision: (test=0.763) recall: (test=0.949) roc_auc: (test=0.870) total time=   0.3s
# [CV 3/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.826) precision: (test=0.768) recall: (test=0.893) roc_auc: (test=0.877) total time=   0.4s
# [CV 4/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.864) precision: (test=0.797) recall: (test=0.944) roc_auc: (test=0.884) total time=   0.3s
# [CV 5/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.864) precision: (test=0.781) recall: (test=0.966) roc_auc: (test=0.886) total time=   0.4s
# [CV 6/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.857) precision: (test=0.790) recall: (test=0.936) roc_auc: (test=0.903) total time=   0.3s
# [CV 7/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.814) precision: (test=0.723) recall: (test=0.931) roc_auc: (test=0.852) total time=   0.3s
# [CV 8/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.839) precision: (test=0.766) recall: (test=0.927) roc_auc: (test=0.877) total time=   0.3s
# [CV 9/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.832) precision: (test=0.763) recall: (test=0.914) roc_auc: (test=0.897) total time=   0.3s
# [CV 10/10] END C=77.80000000000001, kernel=rbf; f1: (test=0.847) precision: (test=0.798) recall: (test=0.901) roc_auc: (test=0.902) total time=   0.3s
# [CV 1/10] END C=77.80000000000001, kernel=linear; f1: (test=0.790) precision: (test=0.688) recall: (test=0.927) roc_auc: (test=0.853) total time=   1.7s
# [CV 2/10] END C=77.80000000000001, kernel=linear; f1: (test=0.804) precision: (test=0.708) recall: (test=0.932) roc_auc: (test=0.821) total time=   1.7s
# [CV 3/10] END C=77.80000000000001, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.829) total time=   1.6s
# [CV 4/10] END C=77.80000000000001, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   1.8s
# [CV 5/10] END C=77.80000000000001, kernel=linear; f1: (test=0.799) precision: (test=0.683) recall: (test=0.961) roc_auc: (test=0.846) total time=   1.6s
# [CV 6/10] END C=77.80000000000001, kernel=linear; f1: (test=0.788) precision: (test=0.687) recall: (test=0.923) roc_auc: (test=0.861) total time=   1.9s
# [CV 7/10] END C=77.80000000000001, kernel=linear; f1: (test=0.754) precision: (test=0.652) recall: (test=0.893) roc_auc: (test=0.795) total time=   1.7s
# [CV 8/10] END C=77.80000000000001, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.844) total time=   1.6s
# [CV 9/10] END C=77.80000000000001, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.855) total time=   1.6s
# [CV 10/10] END C=77.80000000000001, kernel=linear; f1: (test=0.795) precision: (test=0.713) recall: (test=0.897) roc_auc: (test=0.835) total time=   1.6s
# [CV 1/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.657) precision: (test=0.661) recall: (test=0.652) roc_auc: (test=0.678) total time=   0.2s
# [CV 2/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.614) precision: (test=0.609) recall: (test=0.620) roc_auc: (test=0.679) total time=   0.2s
# [CV 3/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.569) precision: (test=0.603) recall: (test=0.538) roc_auc: (test=0.662) total time=   0.2s
# [CV 4/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.623) precision: (test=0.633) recall: (test=0.614) roc_auc: (test=0.672) total time=   0.2s
# [CV 5/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.653) precision: (test=0.644) recall: (test=0.661) roc_auc: (test=0.692) total time=   0.2s
# [CV 6/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.630) precision: (test=0.621) recall: (test=0.639) roc_auc: (test=0.671) total time=   0.2s
# [CV 7/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.603) precision: (test=0.606) recall: (test=0.601) roc_auc: (test=0.623) total time=   0.2s
# [CV 8/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.619) precision: (test=0.621) recall: (test=0.618) roc_auc: (test=0.651) total time=   0.2s
# [CV 9/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.574) precision: (test=0.573) recall: (test=0.575) roc_auc: (test=0.617) total time=   0.2s
# [CV 10/10] END C=77.80000000000001, kernel=sigmoid; f1: (test=0.629) precision: (test=0.640) recall: (test=0.618) roc_auc: (test=0.690) total time=   0.2s
# [CV 1/10] END C=88.9, kernel=poly; f1: (test=0.838) precision: (test=0.784) recall: (test=0.901) roc_auc: (test=0.882) total time=   1.8s
# [CV 2/10] END C=88.9, kernel=poly; f1: (test=0.836) precision: (test=0.755) recall: (test=0.936) roc_auc: (test=0.854) total time=   2.0s
# [CV 3/10] END C=88.9, kernel=poly; f1: (test=0.810) precision: (test=0.754) recall: (test=0.876) roc_auc: (test=0.847) total time=   2.6s
# [CV 4/10] END C=88.9, kernel=poly; f1: (test=0.860) precision: (test=0.786) recall: (test=0.948) roc_auc: (test=0.891) total time=   3.2s
# [CV 5/10] END C=88.9, kernel=poly; f1: (test=0.842) precision: (test=0.763) recall: (test=0.940) roc_auc: (test=0.879) total time=   1.9s
# [CV 6/10] END C=88.9, kernel=poly; f1: (test=0.848) precision: (test=0.785) recall: (test=0.923) roc_auc: (test=0.896) total time=   2.6s
# [CV 7/10] END C=88.9, kernel=poly; f1: (test=0.801) precision: (test=0.718) recall: (test=0.906) roc_auc: (test=0.837) total time=   1.4s
# [CV 8/10] END C=88.9, kernel=poly; f1: (test=0.832) precision: (test=0.763) recall: (test=0.914) roc_auc: (test=0.866) total time=   2.1s
# [CV 9/10] END C=88.9, kernel=poly; f1: (test=0.845) precision: (test=0.777) recall: (test=0.927) roc_auc: (test=0.883) total time=   2.2s
# [CV 10/10] END C=88.9, kernel=poly; f1: (test=0.844) precision: (test=0.798) recall: (test=0.897) roc_auc: (test=0.877) total time=   2.3s
# [CV 1/10] END C=88.9, kernel=rbf; f1: (test=0.850) precision: (test=0.788) recall: (test=0.923) roc_auc: (test=0.888) total time=   0.4s
# [CV 2/10] END C=88.9, kernel=rbf; f1: (test=0.844) precision: (test=0.760) recall: (test=0.949) roc_auc: (test=0.868) total time=   0.4s
# [CV 3/10] END C=88.9, kernel=rbf; f1: (test=0.824) precision: (test=0.768) recall: (test=0.889) roc_auc: (test=0.877) total time=   0.4s
# [CV 4/10] END C=88.9, kernel=rbf; f1: (test=0.864) precision: (test=0.797) recall: (test=0.944) roc_auc: (test=0.884) total time=   0.4s
# [CV 5/10] END C=88.9, kernel=rbf; f1: (test=0.862) precision: (test=0.780) recall: (test=0.961) roc_auc: (test=0.887) total time=   0.4s
# [CV 6/10] END C=88.9, kernel=rbf; f1: (test=0.857) precision: (test=0.790) recall: (test=0.936) roc_auc: (test=0.902) total time=   0.4s
# [CV 7/10] END C=88.9, kernel=rbf; f1: (test=0.814) precision: (test=0.723) recall: (test=0.931) roc_auc: (test=0.850) total time=   0.4s
# [CV 8/10] END C=88.9, kernel=rbf; f1: (test=0.839) precision: (test=0.766) recall: (test=0.927) roc_auc: (test=0.877) total time=   0.4s
# [CV 9/10] END C=88.9, kernel=rbf; f1: (test=0.832) precision: (test=0.763) recall: (test=0.914) roc_auc: (test=0.896) total time=   0.4s
# [CV 10/10] END C=88.9, kernel=rbf; f1: (test=0.844) precision: (test=0.800) recall: (test=0.893) roc_auc: (test=0.901) total time=   0.4s
# [CV 1/10] END C=88.9, kernel=linear; f1: (test=0.790) precision: (test=0.688) recall: (test=0.927) roc_auc: (test=0.853) total time=   2.0s
# [CV 2/10] END C=88.9, kernel=linear; f1: (test=0.804) precision: (test=0.708) recall: (test=0.932) roc_auc: (test=0.821) total time=   2.0s
# [CV 3/10] END C=88.9, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.829) total time=   1.9s
# [CV 4/10] END C=88.9, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   2.0s
# [CV 5/10] END C=88.9, kernel=linear; f1: (test=0.799) precision: (test=0.683) recall: (test=0.961) roc_auc: (test=0.846) total time=   1.9s
# [CV 6/10] END C=88.9, kernel=linear; f1: (test=0.788) precision: (test=0.687) recall: (test=0.923) roc_auc: (test=0.861) total time=   2.0s
# [CV 7/10] END C=88.9, kernel=linear; f1: (test=0.754) precision: (test=0.652) recall: (test=0.893) roc_auc: (test=0.795) total time=   1.9s
# [CV 8/10] END C=88.9, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.844) total time=   1.9s
# [CV 9/10] END C=88.9, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.855) total time=   1.9s
# [CV 10/10] END C=88.9, kernel=linear; f1: (test=0.795) precision: (test=0.713) recall: (test=0.897) roc_auc: (test=0.835) total time=   1.8s
# [CV 1/10] END C=88.9, kernel=sigmoid; f1: (test=0.657) precision: (test=0.661) recall: (test=0.652) roc_auc: (test=0.678) total time=   0.2s
# [CV 2/10] END C=88.9, kernel=sigmoid; f1: (test=0.614) precision: (test=0.609) recall: (test=0.620) roc_auc: (test=0.679) total time=   0.2s
# [CV 3/10] END C=88.9, kernel=sigmoid; f1: (test=0.569) precision: (test=0.603) recall: (test=0.538) roc_auc: (test=0.662) total time=   0.2s
# [CV 4/10] END C=88.9, kernel=sigmoid; f1: (test=0.623) precision: (test=0.633) recall: (test=0.614) roc_auc: (test=0.672) total time=   0.2s
# [CV 5/10] END C=88.9, kernel=sigmoid; f1: (test=0.653) precision: (test=0.644) recall: (test=0.661) roc_auc: (test=0.692) total time=   0.2s
# [CV 6/10] END C=88.9, kernel=sigmoid; f1: (test=0.630) precision: (test=0.621) recall: (test=0.639) roc_auc: (test=0.671) total time=   0.2s
# [CV 7/10] END C=88.9, kernel=sigmoid; f1: (test=0.603) precision: (test=0.606) recall: (test=0.601) roc_auc: (test=0.623) total time=   0.2s
# [CV 8/10] END C=88.9, kernel=sigmoid; f1: (test=0.619) precision: (test=0.621) recall: (test=0.618) roc_auc: (test=0.651) total time=   0.2s
# [CV 9/10] END C=88.9, kernel=sigmoid; f1: (test=0.574) precision: (test=0.573) recall: (test=0.575) roc_auc: (test=0.617) total time=   0.2s
# [CV 10/10] END C=88.9, kernel=sigmoid; f1: (test=0.629) precision: (test=0.640) recall: (test=0.618) roc_auc: (test=0.690) total time=   0.2s
# [CV 1/10] END C=100.0, kernel=poly; f1: (test=0.838) precision: (test=0.784) recall: (test=0.901) roc_auc: (test=0.883) total time=   2.1s
# [CV 2/10] END C=100.0, kernel=poly; f1: (test=0.838) precision: (test=0.756) recall: (test=0.940) roc_auc: (test=0.854) total time=   2.5s
# [CV 3/10] END C=100.0, kernel=poly; f1: (test=0.810) precision: (test=0.754) recall: (test=0.876) roc_auc: (test=0.847) total time=   2.8s
# [CV 4/10] END C=100.0, kernel=poly; f1: (test=0.860) precision: (test=0.786) recall: (test=0.948) roc_auc: (test=0.891) total time=   3.9s
# [CV 5/10] END C=100.0, kernel=poly; f1: (test=0.844) precision: (test=0.766) recall: (test=0.940) roc_auc: (test=0.879) total time=   2.0s
# [CV 6/10] END C=100.0, kernel=poly; f1: (test=0.850) precision: (test=0.785) recall: (test=0.927) roc_auc: (test=0.896) total time=   2.4s
# [CV 7/10] END C=100.0, kernel=poly; f1: (test=0.802) precision: (test=0.716) recall: (test=0.910) roc_auc: (test=0.837) total time=   1.5s
# [CV 8/10] END C=100.0, kernel=poly; f1: (test=0.832) precision: (test=0.763) recall: (test=0.914) roc_auc: (test=0.866) total time=   3.0s
# [CV 9/10] END C=100.0, kernel=poly; f1: (test=0.845) precision: (test=0.777) recall: (test=0.927) roc_auc: (test=0.882) total time=   3.4s
# [CV 10/10] END C=100.0, kernel=poly; f1: (test=0.844) precision: (test=0.798) recall: (test=0.897) roc_auc: (test=0.877) total time=   2.0s
# [CV 1/10] END C=100.0, kernel=rbf; f1: (test=0.851) precision: (test=0.793) recall: (test=0.918) roc_auc: (test=0.887) total time=   0.4s
# [CV 2/10] END C=100.0, kernel=rbf; f1: (test=0.844) precision: (test=0.762) recall: (test=0.944) roc_auc: (test=0.868) total time=   0.4s
# [CV 3/10] END C=100.0, kernel=rbf; f1: (test=0.824) precision: (test=0.768) recall: (test=0.889) roc_auc: (test=0.878) total time=   0.4s
# [CV 4/10] END C=100.0, kernel=rbf; f1: (test=0.864) precision: (test=0.797) recall: (test=0.944) roc_auc: (test=0.884) total time=   0.4s
# [CV 5/10] END C=100.0, kernel=rbf; f1: (test=0.862) precision: (test=0.780) recall: (test=0.961) roc_auc: (test=0.888) total time=   0.4s
# [CV 6/10] END C=100.0, kernel=rbf; f1: (test=0.858) precision: (test=0.793) recall: (test=0.936) roc_auc: (test=0.902) total time=   0.4s
# [CV 7/10] END C=100.0, kernel=rbf; f1: (test=0.814) precision: (test=0.723) recall: (test=0.931) roc_auc: (test=0.850) total time=   0.4s
# [CV 8/10] END C=100.0, kernel=rbf; f1: (test=0.839) precision: (test=0.766) recall: (test=0.927) roc_auc: (test=0.877) total time=   0.4s
# [CV 9/10] END C=100.0, kernel=rbf; f1: (test=0.832) precision: (test=0.763) recall: (test=0.914) roc_auc: (test=0.895) total time=   0.4s
# [CV 10/10] END C=100.0, kernel=rbf; f1: (test=0.844) precision: (test=0.800) recall: (test=0.893) roc_auc: (test=0.902) total time=   0.4s
# [CV 1/10] END C=100.0, kernel=linear; f1: (test=0.790) precision: (test=0.688) recall: (test=0.927) roc_auc: (test=0.853) total time=   2.2s
# [CV 2/10] END C=100.0, kernel=linear; f1: (test=0.804) precision: (test=0.708) recall: (test=0.932) roc_auc: (test=0.821) total time=   2.1s
# [CV 3/10] END C=100.0, kernel=linear; f1: (test=0.779) precision: (test=0.698) recall: (test=0.880) roc_auc: (test=0.829) total time=   2.0s
# [CV 4/10] END C=100.0, kernel=linear; f1: (test=0.816) precision: (test=0.714) recall: (test=0.953) roc_auc: (test=0.869) total time=   2.1s
# [CV 5/10] END C=100.0, kernel=linear; f1: (test=0.799) precision: (test=0.683) recall: (test=0.961) roc_auc: (test=0.846) total time=   2.1s
# [CV 6/10] END C=100.0, kernel=linear; f1: (test=0.788) precision: (test=0.687) recall: (test=0.923) roc_auc: (test=0.861) total time=   2.5s
# [CV 7/10] END C=100.0, kernel=linear; f1: (test=0.754) precision: (test=0.652) recall: (test=0.893) roc_auc: (test=0.795) total time=   2.2s
# [CV 8/10] END C=100.0, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.844) total time=   2.1s
# [CV 9/10] END C=100.0, kernel=linear; f1: (test=0.800) precision: (test=0.704) recall: (test=0.927) roc_auc: (test=0.855) total time=   2.2s
# [CV 10/10] END C=100.0, kernel=linear; f1: (test=0.795) precision: (test=0.713) recall: (test=0.897) roc_auc: (test=0.835) total time=   2.0s
# [CV 1/10] END C=100.0, kernel=sigmoid; f1: (test=0.657) precision: (test=0.661) recall: (test=0.652) roc_auc: (test=0.678) total time=   0.2s
# [CV 2/10] END C=100.0, kernel=sigmoid; f1: (test=0.614) precision: (test=0.609) recall: (test=0.620) roc_auc: (test=0.679) total time=   0.2s
# [CV 3/10] END C=100.0, kernel=sigmoid; f1: (test=0.569) precision: (test=0.603) recall: (test=0.538) roc_auc: (test=0.662) total time=   0.2s
# [CV 4/10] END C=100.0, kernel=sigmoid; f1: (test=0.623) precision: (test=0.633) recall: (test=0.614) roc_auc: (test=0.672) total time=   0.2s
# [CV 5/10] END C=100.0, kernel=sigmoid; f1: (test=0.653) precision: (test=0.644) recall: (test=0.661) roc_auc: (test=0.692) total time=   0.2s
# [CV 6/10] END C=100.0, kernel=sigmoid; f1: (test=0.630) precision: (test=0.621) recall: (test=0.639) roc_auc: (test=0.671) total time=   0.2s
# [CV 7/10] END C=100.0, kernel=sigmoid; f1: (test=0.603) precision: (test=0.606) recall: (test=0.601) roc_auc: (test=0.623) total time=   0.2s
# [CV 8/10] END C=100.0, kernel=sigmoid; f1: (test=0.618) precision: (test=0.618) recall: (test=0.618) roc_auc: (test=0.651) total time=   0.2s
# [CV 9/10] END C=100.0, kernel=sigmoid; f1: (test=0.581) precision: (test=0.579) recall: (test=0.584) roc_auc: (test=0.618) total time=   0.2s
# [CV 10/10] END C=100.0, kernel=sigmoid; f1: (test=0.629) precision: (test=0.640) recall: (test=0.618) roc_auc: (test=0.690) total time=   0.2s
# SVC(C=77.80000000000001)
# {'C': 77.80000000000001, 'kernel': 'rbf'}
# [{'C': 0.1, 'kernel': 'poly'}, {'C': 0.1, 'kernel': 'rbf'}, {'C': 0.1, 'kernel': 'linear'}, {'C': 0.1, 'kernel': 'sigmoid'}, {'C': 11.200000000000001, 'kernel': 'poly'}, {'C': 11.200000000000001, 'kernel': 'rbf'}, {'C': 11.200000000000001, 'kernel': 'linear'}, {'C': 11.200000000000001, 'kernel': 'sigmoid'}, {'C': 22.300000000000004, 'kernel': 'poly'}, {'C': 22.300000000000004, 'kernel': 'rbf'}, {'C': 22.300000000000004, 'kernel': 'linear'}, {'C': 22.300000000000004, 'kernel': 'sigmoid'}, {'C': 33.400000000000006, 'kernel': 'poly'}, {'C': 33.400000000000006, 'kernel': 'rbf'}, {'C': 33.400000000000006, 'kernel': 'linear'}, {'C': 33.400000000000006, 'kernel': 'sigmoid'}, {'C': 44.50000000000001, 'kernel': 'poly'}, {'C': 44.50000000000001, 'kernel': 'rbf'}, {'C': 44.50000000000001, 'kernel': 'linear'}, {'C': 44.50000000000001, 'kernel': 'sigmoid'}, {'C': 55.60000000000001, 'kernel': 'poly'}, {'C': 55.60000000000001, 'kernel': 'rbf'}, {'C': 55.60000000000001, 'kernel': 'linear'}, {'C': 55.60000000000001, 'kernel': 'sigmoid'}, {'C': 66.7, 'kernel': 'poly'}, {'C': 66.7, 'kernel': 'rbf'}, {'C': 66.7, 'kernel': 'linear'}, {'C': 66.7, 'kernel': 'sigmoid'}, {'C': 77.80000000000001, 'kernel': 'poly'}, {'C': 77.80000000000001, 'kernel': 'rbf'}, {'C': 77.80000000000001, 'kernel': 'linear'}, {'C': 77.80000000000001, 'kernel': 'sigmoid'}, {'C': 88.9, 'kernel': 'poly'}, {'C': 88.9, 'kernel': 'rbf'}, {'C': 88.9, 'kernel': 'linear'}, {'C': 88.9, 'kernel': 'sigmoid'}, {'C': 100.0, 'kernel': 'poly'}, {'C': 100.0, 'kernel': 'rbf'}, {'C': 100.0, 'kernel': 'linear'}, {'C': 100.0, 'kernel': 'sigmoid'}]
# <AxesSubplot:xlabel='C', ylabel='f1'>

# %% [markdown]
#  ##### Results of SVM algorithm gridseach for best parameters:

# %% [markdown]
# #### Fit final model using SVC algorithm with optimized parameters found prior

# %%
print(clf.best_params_)
# Out:
# {'C': 77.80000000000001, 'kernel': 'rbf'}

# %% [markdown]
# Gridseach shows the best params above. However, this is a high c value, which would make the model not able to generalize well enough for the novel testing dataset. The F1 score of c-value of 33.4 is tested below and is shown to also be very robust for dataset. Setting the c-value to 33.4 instead of the selected 77.8 will reduce performance on the training set but it should help the model predict novel data. The two confusion matrix below show some of the loss by choosing a c-value of 33.4 instead of 77.8.

# %% [markdown]
# # Justin, can you check this section. The fitting of the model is from the training data but the predictions are done on the whole dataset (X). Im not sure if that is the correct way to do it. Its mentioned in the assignment description to do it on both testing and training splits.
#
# ### Optimize paramaters for final model
# #### Fit testing model using SVC algorithm with optimized parameters found prior c-value = 77.8, kernel= 'rbf'

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# Build model and predict
testing_model = svm.SVC(C=77.8,kernel='rbf')
testing_model.fit(X_train, Y_train)
Y_pre=testing_model.predict(X)

print('Model when c-value = 77.8, kernel = rbf')
print('Accuracy:', accuracy_score(Y, Y_pre))
print('Precision:',precision_score(Y, Y_pre))
print('Recall:', recall_score(Y, Y_pre))
print('Confusion Matrix', confusion_matrix(Y, Y_pre))
plot_confusion_matrix(testing_model, X, Y)
# Out:
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Model when c-value = 77.8, kernel = rbf
# Accuracy: 0.8391126426879173
# Precision: 0.7857915614857555
# Recall: 0.9343910806174958
# Confusion Matrix [[1717  594]
#  [ 153 2179]]

# %% [markdown]
# ##### Results
# Choosing c-value of 77.8 provides for a very robust model. The confusion matrix shows the model did very well predicting:
#
# Upper-Left: Shows how many True Positive (TP) cases the model predicted  correctly.
#
# Lower-Left: Shows how many False Positive (FP) cases the model predicted incorrectly.
#
# Upper-Right: Shows how many False Negatives (FN) the model predicted incorrectly.
#
# Lower-Right: Shows how many True Negative (TN)cases the model predicted  correctly.

# %% [markdown]
# #### Fit testing model using SVC algorithm with optimized parameters found prior c-value = 33.4, kernel= 'rbf'

# %%
print('Model when c-value = 33.4, kernel = rbf')
final_model = svm.SVC(C=33.4,kernel='rbf')
final_model.fit(X_train, Y_train)
Y_pre=final_model.predict(X)

print('Accuracy:', accuracy_score(Y, Y_pre))
print('Precision:',precision_score(Y, Y_pre))
print('Recall:', recall_score(Y, Y_pre))
print('Confusion Matrix', confusion_matrix(Y, Y_pre))
plot_confusion_matrix(final_model, X, Y)
# Out:
# Model when c-value = 33.4, kernel = rbf
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Accuracy: 0.8369588628042214
# Precision: 0.7807486631016043
# Recall: 0.9391080617495712
# Confusion Matrix [[1696  615]
#  [ 142 2190]]

# %% [markdown]
# ##### Results
# By setting the c-value lower, to 33.4 it increases the FP and FN of the model a small amount but should provide for a more robust model. These pararmeters will be chosen for the final model. We can also see that Recall, precision & accuracy have gone down a bit. Choosing the lower c-value we hope the model can generalize better.
#
# Choosing c-value of 33.4 still provides for a very robust model that should perform better on novel datasets. The confusion matrix shows the model did very well predicting:
#
# Upper-Left: Shows how many True Positive (TP) cases the model predicted  correctly.
#
# Lower-Left: Shows how many False Positive (FP) cases the model predicted incorrectly.
#
# Upper-Right: Shows how many False Negatives (FN) the model predicted incorrectly.
#
# Lower-Right: Shows how many True Negative (TN)cases the model predicted  correctly.

# %% [markdown]
# #### Final Model Parameters: C-value = 33.4, kernel='rbf'

# %% [markdown]
# ##### Plot Accuracy, Precision, Recall and ROC chart of final model for final model

# %%
print('Accuracy:', accuracy_score(Y, Y_pre))
print('Precision:',precision_score(Y, Y_pre))
print('Recall:', recall_score(Y, Y_pre))
# Out:
# Accuracy: 0.8429894464785699
# Precision: 0.7857397504456328
# Recall: 0.9451114922813036

# %% [markdown]
# ##### ROC plot of final model using SVM algorithm with optimized parameters

# %%
# ROC plot & AUC score of final model
auc_score = roc_auc_score(Y,Y_pre)
print(auc_score)
plot_roc_curve(clf,X,Y)
# Out:
# 0.8425254562228672
# /Users/jprince/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metrics.RocCurveDisplay.from_predictions` or :meth:`sklearn.metrics.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ##### Results

# %% [markdown]
# #### Plot AUC & F1 charts for testing/training split using final model

# %% [markdown]
# ## Part B

# %% [markdown]
# #### Based on your analyses, describe the most important characteristics of a phishing website
# One of the issues with using a non-linear SVC is that it is currently impossible to calculate feature importance. However, we can use our Random Forest Classifier to determine the importance of each feature and rank them.

# %%
rfclf=RandomForestClassifier(n_estimators=1000, max_depth=7,random_state=1, max_samples=400)
rfclf.fit(X_train, Y_train)
imps = rfclf.feature_importances_
sort_ind = np.argsort(imps)[::-1]
feature_labels = dfTrain3.columns[1:]
for f in range (X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, feature_labels[sort_ind[f]], imps[sort_ind[f]]))
# Out:
#  1) TildeSymbol                    0.302816
#  2) IpAddress                      0.174763
#  3) RandomString                   0.169859
#  4) NoHttps                        0.162910
#  5) DoubleSlashInPath              0.134389
#  6) DomainInPaths                  0.029354
#  7) DomainInSubdomains             0.025911

# %% [markdown]
# #### Export final model using pickle

# %%
import pickle
pickle.dump(final_model,open('test','wb'))

# %% [markdown]
# Analysis of testing data is done in a seperate notebook file. This was done to seperate the data completly and allow for less variable confusion.
#
# #### How would you explain your results to an upper-tier manager to explain your work in this project clearly and briefly? Write a page exclusive summary to describe your work, its importance,  your conclusions, and how your company can benefit from this work.
#
# In our work we created a AI model that differentiate between a normal and phishing emails. By analyzing, testing and processing data on phishing and regular emails we were able to create a model that can differentiate with 85% accuracy.
# The work we did with AI and phishing emails is important for several reasons. AI models have the potential to automate task that can be costly and time consuming. Phishing attacks are one of the most, if not the most common type of threat. A successful phishing attack can have serious detrimental effects on a organization and its employees. Having the ability to automaticallly detect phishing emails can be very benificial.
#
# The company can benifit from our work a several ways. First, is it reduces the number of successful phishing attacks by detecting them automaticallly. Next, is that research in to AI and classification models could potentially be expanded in to other areas. We could potentially build models to detect other threats, or reduce workloads of employeee's. It also removes the stress of an employee having to make the determination themselves. As technology to detect malicious activity becomes more advanced, so does the attack methods. Phishing attacks are becoming more and more convincing.
